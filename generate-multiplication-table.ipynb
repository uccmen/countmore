# %%
for i in range(1, 21):
    for j in range(1, 21):
        print(f"{i}x{j}={i*j}")
# Out:
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# 1x10=10
# 1x11=11
# 1x12=12
# 1x13=13
# 1x14=14
# 1x15=15
# 1x16=16
# 1x17=17
# 1x18=18
# 1x19=19
# 1x20=20
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20
# 2x11=22
# 2x12=24
# 2x13=26
# 2x14=28
# 2x15=30
# 2x16=32
# 2x17=34
# 2x18=36
# 2x19=38
# 2x20=40
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 3x10=30
# 3x11=33
# 3x12=36
# 3x13=39
# 3x14=42
# 3x15=45
# 3x16=48
# 3x17=51
# 3x18=54
# 3x19=57
# 3x20=60
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# 4x10=40
# 4x11=44
# 4x12=48
# 4x13=52
# 4x14=56
# 4x15=60
# 4x16=64
# 4x17=68
# 4x18=72
# 4x19=76
# 4x20=80
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 5x10=50
# 5x11=55
# 5x12=60
# 5x13=65
# 5x14=70
# 5x15=75
# 5x16=80
# 5x17=85
# 5x18=90
# 5x19=95
# 5x20=100
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# ...
