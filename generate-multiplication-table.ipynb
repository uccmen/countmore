# %%
with open("multiplication-table.txt", "w") as file:
    for i in range(1, 2001):
        for j in range(1, 21):
            file.write(f"{i}x{j}={i*j}\n")
    for i in range(1, 21):
        for j in range(1, 2001):
            file.write(f"{i}x{j}={i*j}\n")
            print(f"{i}x{j}={i*j}")# comment out this line if you're generating a large timetable
# Out:
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# 1x10=10
# 1x11=11
# 1x12=12
# 1x13=13
# 1x14=14
# 1x15=15
# 1x16=16
# 1x17=17
# 1x18=18
# 1x19=19
# 1x20=20
# 1x21=21
# 1x22=22
# 1x23=23
# 1x24=24
# 1x25=25
# 1x26=26
# 1x27=27
# 1x28=28
# 1x29=29
# 1x30=30
# 1x31=31
# 1x32=32
# 1x33=33
# 1x34=34
# 1x35=35
# 1x36=36
# 1x37=37
# 1x38=38
# 1x39=39
# 1x40=40
# 1x41=41
# 1x42=42
# 1x43=43
# 1x44=44
# 1x45=45
# 1x46=46
# 1x47=47
# 1x48=48
# 1x49=49
# 1x50=50
# 1x51=51
# 1x52=52
# 1x53=53
# 1x54=54
# 1x55=55
# 1x56=56
# 1x57=57
# 1x58=58
# 1x59=59
# 1x60=60
# 1x61=61
# 1x62=62
# 1x63=63
# 1x64=64
# 1x65=65
# 1x66=66
# 1x67=67
# 1x68=68
# 1x69=69
# 1x70=70
# 1x71=71
# 1x72=72
# 1x73=73
# 1x74=74
# 1x75=75
# 1x76=76
# 1x77=77
# 1x78=78
# 1x79=79
# 1x80=80
# 1x81=81
# 1x82=82
# 1x83=83
# 1x84=84
# 1x85=85
# 1x86=86
# 1x87=87
# 1x88=88
# 1x89=89
# 1x90=90
# 1x91=91
# 1x92=92
# 1x93=93
# 1x94=94
# 1x95=95
# 1x96=96
# 1x97=97
# 1x98=98
# 1x99=99
# 1x100=100
# 1x101=101
# ...
